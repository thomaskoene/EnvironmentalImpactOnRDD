# %%
# !pip install pylabel
from pylabel import importer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
dataset = importer.ImportVOC(path="/gpfs/home5/tkoene/all_countries/labels_without_valset/")

dataset.export.ExportToYoloV5()
# Out:
# ...
# Exporting YOLO files...: 100%|██████████| 26261/26261 [02:17<00:00, 190.74it/s]
# ['training/dataset.yaml',
#  'training/labels/China_MotorBike_000459.txt',
#  'training/labels/Japan_008977.txt',
#  'training/labels/China_Drone_000585.txt',
#  'training/labels/India_004205.txt',
#  'training/labels/India_007801.txt',
#  'training/labels/Czech_001277.txt',
#  'training/labels/United_States_001121.txt',
#  'training/labels/Japan_012084.txt',
#  'training/labels/Norway_002679.txt',
#  'training/labels/Japan_001850.txt',
#  'training/labels/United_States_004134.txt',
#  'training/labels/United_States_004194.txt',
#  'training/labels/Japan_010957.txt',
#  'training/labels/Japan_002284.txt',
#  'training/labels/United_States_002545.txt',
#  'training/labels/China_MotorBike_000222.txt',
#  'training/labels/China_Drone_001779.txt',
#  'training/labels/Japan_013120.txt',
#  'training/labels/India_004449.txt',
#  'training/labels/Japan_011427.txt',
#  'training/labels/Japan_002476.txt',
# ...
