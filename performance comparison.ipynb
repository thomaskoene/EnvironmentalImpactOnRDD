# %%
import pandas as pd

# %%
China_Drone = {'metrics/precision(B)': 0.5089556863345432, 'metrics/recall(B)': 0.41118501198108004, 'metrics/mAP50(B)': 0.43981058695716535, 'metrics/mAP50-95(B)': 0.2525529384579092, 'fitness': 0.2712787033078348}
China_MotorBike = {'metrics/precision(B)': 0.842532151864547, 'metrics/recall(B)': 0.7638964763690084, 'metrics/mAP50(B)': 0.8462683507216078, 'metrics/mAP50-95(B)': 0.5487144681853965, 'fitness': 0.5784698564390176}
Czech = {'metrics/precision(B)': 0.20827427288723038, 'metrics/recall(B)': 0.16609777419767663, 'metrics/mAP50(B)': 0.11522658493963553, 'metrics/mAP50-95(B)': 0.039513608249910744, 'fitness': 0.04708490591888322}
India = {'metrics/precision(B)': 0.5765913623454217, 'metrics/recall(B)': 0.2505979340720683, 'metrics/mAP50(B)': 0.2341042335562332, 'metrics/mAP50-95(B)': 0.10913611400519954, 'fitness': 0.12163292596030291}
Japan = {'metrics/precision(B)': 0.637073156335231, 'metrics/recall(B)': 0.5954761969268724, 'metrics/mAP50(B)': 0.6379186595386079, 'metrics/mAP50-95(B)': 0.3604147239777293, 'fitness': 0.3881651175338171}
Norway = {'metrics/precision(B)': 0.38215400018946993, 'metrics/recall(B)': 0.10046107617906674, 'metrics/mAP50(B)': 0.06405661206219282, 'metrics/mAP50-95(B)': 0.024065710698404998, 'fitness': 0.02806480083478378}
United_States = {'metrics/precision(B)': 0.700631874948364, 'metrics/recall(B)': 0.45164390814106437, 'metrics/mAP50(B)': 0.47233331755989716, 'metrics/mAP50-95(B)': 0.26014449316992344, 'fitness': 0.28136337560892083}

df = pd.DataFrame({'China_Drone': China_Drone, 'China_MotorBike': China_MotorBike, 'Czech': Czech, 'India': India, 'Japan': Japan, 'Norway': Norway, 'United_States': United_States}).T

df.plot()
# Out:
# <Axes: >

# %%
cloudy = {'metrics/precision(B)': 0.42378839589068074, 'metrics/recall(B)': 0.07643464757719817, 'metrics/mAP50(B)': 0.08268198327512233, 'metrics/mAP50-95(B)': 0.03816825811923179, 'fitness': 0.04261963063482084}
rain = {'metrics/precision(B)': 0.5722428093833366, 'metrics/recall(B)': 0.3301582313122679, 'metrics/mAP50(B)': 0.36820555945074784, 'metrics/mAP50-95(B)': 0.2105065006468551, 'fitness': 0.2262764065272444}
shine = {'metrics/precision(B)': 0.6014557671279859, 'metrics/recall(B)': 0.32743163983650664, 'metrics/mAP50(B)': 0.3370524227338694, 'metrics/mAP50-95(B)': 0.1682258775532084, 'fitness': 0.1851085320712745}
sunrise = {'metrics/precision(B)': 0.0013593941500161487, 'metrics/recall(B)': 0.17763005420297134, 'metrics/mAP50(B)': 0.011125036065827452, 'metrics/mAP50-95(B)': 0.004051731633765993, 'fitness': 0.004759062076972139}

df = pd.DataFrame({'cloudy': cloudy, 'rain': rain, 'shine': shine, 'sunrise': sunrise}).T

df.plot()

# looks like shine model performs best, rain second and cloudy third
# Out:
# <Axes: >

# %%
# trained on everything and evaluated on country hold out set

all_countries = {'metrics/precision(B)': 0.4311622433164863, 'metrics/recall(B)': 0.2955293368191361, 'metrics/mAP50(B)': 0.3019710326206831, 'metrics/mAP50-95(B)': 0.16128584721314868, 'fitness': 0.17535436575390212}
China_Drone = {'metrics/precision(B)': 0.33701674245839275, 'metrics/recall(B)': 0.3202133907186783, 'metrics/mAP50(B)': 0.2726976926424472, 'metrics/mAP50-95(B)': 0.1375324531564496, 'fitness': 0.1510489771050494}
China_MotorBike = {'metrics/precision(B)': 0.0054270153583977805, 'metrics/recall(B)': 0.25721666128758786, 'metrics/mAP50(B)': 0.0038725612184810966, 'metrics/mAP50-95(B)': 0.0017744699248763676, 'fitness': 0.0019842790542368405}
Czech = {'metrics/precision(B)': 0.002516621360078063, 'metrics/recall(B)': 0.20859823563203206, 'metrics/mAP50(B)': 0.0017010093954116564, 'metrics/mAP50-95(B)': 0.0006481918898310656, 'fitness': 0.0007534736403891247}
India = {'metrics/precision(B)': 0.004397403192130311, 'metrics/recall(B)': 0.012771096862283874, 'metrics/mAP50(B)': 0.0023777795659628027, 'metrics/mAP50-95(B)': 0.0010549162738585887, 'fitness': 0.0011872026030690101}
Japan = {'metrics/precision(B)': 0.002856851955578817, 'metrics/recall(B)': 0.10943006596197792, 'metrics/mAP50(B)': 0.0015787303515698585, 'metrics/mAP50-95(B)': 0.0007327950680525609, 'fitness': 0.0008173885964042907}
Norway = {'metrics/precision(B)': 0.024873726814299092, 'metrics/recall(B)': 0.24196670217581395, 'metrics/mAP50(B)': 0.01369034340285927, 'metrics/mAP50-95(B)': 0.006466320965053765, 'fitness': 0.007188723208834316}
United_States = {'metrics/precision(B)': 0.42954765731838573, 'metrics/recall(B)': 0.41119720874792326, 'metrics/mAP50(B)': 0.42196276076588435, 'metrics/mAP50-95(B)': 0.2256350016703766, 'fitness': 0.24526777757992738}

df = pd.DataFrame({'All_countries': all_countries, 
                   'United_States': United_States, 
                   'China_Drone': China_Drone, 
                   'Norway': Norway, 
                   'China_MotorBike': China_MotorBike, 
                   'Czech': Czech, 
                   'Japan': Japan, 
                   'India': India
                   }).T

df = df.rename(columns={'metrics/precision(B)': 'precision', 
                        'metrics/recall(B)':'recall', 
                        'metrics/mAP50(B)': 'mAP50', 
                        'metrics/mAP50-95(B)': 'mAP50-95'})

df = df[['precision', 'recall', 'fitness']]

df.plot(kind='bar', figsize=(10, 5), title='Performance of road damage detection of images from different countries')
df.recall
# Out:
# All_countries      0.295529
# United_States      0.411197
# China_Drone        0.320213
# Norway             0.241967
# China_MotorBike    0.257217
# Czech              0.208598
# Japan              0.109430
# India              0.012771
# Name: recall, dtype: float64

# %%
# Best is United States, then China Drone, Norway, China MotorBike, Czech, Japan and lastly India

# %%
# trained on everything and evaluated on weather circumstance hold out set

random = {'metrics/precision(B)': 0.4311622433164863, 'metrics/recall(B)': 0.2955293368191361, 'metrics/mAP50(B)': 0.3019710326206831, 'metrics/mAP50-95(B)': 0.16128584721314868, 'fitness': 0.17535436575390212}
cloudy = {'metrics/precision(B)': 0.2716280459031882, 'metrics/recall(B)': 0.040046906222583514, 'metrics/mAP50(B)': 0.037101615083140665, 'metrics/mAP50-95(B)': 0.017428279844673482, 'fitness': 0.019395613368520203}
rain = {'metrics/precision(B)': 0.0878045939154715, 'metrics/recall(B)': 0.018848488422349482, 'metrics/mAP50(B)': 0.0023567999266647607, 'metrics/mAP50-95(B)': 0.001059249462785592, 'fitness': 0.001189004509173509}
shine = {'metrics/precision(B)': 0.010874257359623123, 'metrics/recall(B)': 0.2752798019023925, 'metrics/mAP50(B)': 0.007096944727736908, 'metrics/mAP50-95(B)': 0.00397444699760871, 'fitness': 0.00428669677062153}
sunrise = {'metrics/precision(B)': 0.0058827568303061175, 'metrics/recall(B)': 0.3448544724539249, 'metrics/mAP50(B)': 0.010719548681012159, 'metrics/mAP50-95(B)': 0.005921226112456045, 'fitness': 0.006401058369311657}

df = pd.DataFrame({'random': random, 
                   'cloudy': cloudy, 
                   'rain': rain, 
                   'sunrise': sunrise, 
                   'shine': shine, 

                  }).T

df = df.rename(columns={'metrics/precision(B)': 'precision', 
                        'metrics/recall(B)':'recall', 
                        'metrics/mAP50(B)': 'mAP50', 
                        'metrics/mAP50-95(B)': 'mAP50-95'})

df = df[['precision', 'recall', 'fitness']]

df.plot(kind='bar', title='Performance of road damage detection of images taken under different weather circumstances')
# Out:
# <Axes: title={'center': 'Performance of road damage detection of images taken under different weather circumstances'}>

# %%
# cloudy performs best, then sunrise, shine and lastly rain

# high recall (sunrise and shine) -> completeness of positive predictions -> detects more, but not necessarily accurate
# high precision (cloudy and rain) -> accuracy of positive predictions -> detects less, but more accurate
